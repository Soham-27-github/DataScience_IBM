# %% [markdown]
# # Data Science Exercises

# %% [markdown]
# # Introduction
#
# This notebook contains a collection of exercises focused on data science languages, libraries, and tools. It is designed for individuals interested in enhancing their understanding of data science concepts and practices. The exercises will cover various aspects of data science, including practical coding tasks and theoretical knowledge.

# %% [markdown]
# # Data Science Languages
#
# - Python
# - R
# - SQL
# - Julia
# - Java
# - Scala

# %% [markdown]
# # Data Science Libraries
#
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - Keras

# %% [markdown]
# # Data Science Tools
#
# | Tool          | Description                             |
# |---------------|-----------------------------------------|
# | Jupyter       | Interactive computing environment       |
# | RStudio       | IDE for R programming                   |
# | Anaconda      | Package manager for data science tools   |
# | GitHub        | Version control and collaboration        |

# %% [markdown]
# # Arithmetic Expression Examples
#
# This cell will introduce examples of arithmetic expressions such as addition, subtraction, multiplication, and division.

# %%
# Multiply and add numbers
a = 5
b = 10
result = a * 2 + b
result

# %%
# Convert minutes to hours
def convert_minutes_to_hours(minutes):
    hours = minutes / 60
    return hours

# Example usage
convert_minutes_to_hours(120)

# %% [markdown]
# # Objectives
#
# - Understand the basics of data science languages and libraries.
# - Learn to perform arithmetic operations using Python.
# - Explore data science tools and their functionalities.
# - Gain insights into practical applications of data science.

# %% [markdown]
# # Author
#
# Name: Soham Kamate
# Role: Student interested in data science insights.
